# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors

# %matplotlib inline

plt.style.use("dark_background")
cmap = "viridis"
pi_chr = chr(960)

# %%
x_max = 4
y_max = 3
x, y = np.meshgrid(
    np.linspace(-x_max, x_max, 4*x_max+1), 
    np.linspace(-y_max, y_max, 4*y_max+1)
)

# mag = np.hypot(1, dy)
u = 1/np.sqrt(2)
v = u
plt.quiver(
    x, y, 
    u, v, 
    1, 
    cmap = cmap,
    norm = colors.Normalize(vmin=0, vmax=2),
    pivot = "mid",
    scale = 16,
)
plt.colorbar()
plt.title("dy/dx = 1")
plt.tight_layout()
# plt.savefig(f"./svg/constant_slope_field_{cmap}.svg")

plt.show()

# %%
x_max = 4
y_max = 3
x, y = np.meshgrid(
    np.linspace(-x_max, x_max, 4*x_max+1), 
    np.linspace(-y_max, y_max, 4*y_max+1)
)

mag = np.hypot(1, x)
u = 1/mag
v = x/mag
plt.quiver(
    x, y, 
    u, v, 
    np.abs(x), 
    cmap = cmap,
    pivot = "mid",
    scale = 19,
)
plt.colorbar()
plt.title("dy/dx = x")
plt.tight_layout()
# plt.savefig(f"./svg/parabola_slope_field_{cmap}.svg")

plt.show()

# %%
x_max = 8
y_max = 6
x, y = np.meshgrid(
    np.linspace(-x_max, x_max, 2*x_max+1), 
    np.linspace(-y_max, y_max, 2*y_max+1)
)

mag = np.hypot(1, y)
u = 1/mag
v = y/mag
plt.quiver(
    x, y, 
    u, v, 
    np.abs(y), 
    cmap = cmap,
    pivot = "mid",
    scale = 19,
)
plt.colorbar()
plt.title("dy/dx = y")
plt.tight_layout()
# plt.savefig(f"./svg/exp_x_slope_field_{cmap}.svg")

plt.show()

# %%
x_max = 3*np.pi/2
y_max = 9*np.pi/8
x, y = np.meshgrid(
    np.linspace(-x_max, x_max, 19), 
    np.linspace(-y_max, y_max, 13)
)

dy = np.cos(x)
mag = np.hypot(1, dy)
u = 1/mag
v = dy/mag
plt.quiver(
    x, y, 
    u, v, 
    np.abs(dy), 
    cmap = cmap,
    pivot = "mid",
    scale = 19,
)
plt.tight_layout()
plt.colorbar()
plt.title("dy/dx = cos(x)")
plt.tight_layout()
# plt.savefig(f"./svg/sin_x_slope_field_{cmap}.svg")

plt.show()

# %%
x_max = 3*np.pi/2
y_max = 9*np.pi/8
x, y = np.meshgrid(
    np.linspace(-x_max, x_max, 19), 
    np.linspace(-y_max, y_max, 13)
)

dy = -np.sin(x)
mag = np.hypot(1, dy)
u = 1/mag
v = dy/mag
plt.quiver(
    x, y, 
    u, v, 
    np.abs(dy), 
    cmap = cmap,
    pivot = "mid",
    scale = 19,
)
plt.tight_layout()
plt.colorbar()
plt.title("dy/dx = -sin(x)")
plt.tight_layout()
# plt.savefig(f"./svg/cos_x_slope_field_{cmap}.svg")

plt.show()

# %%
x_max = 4
y_max = 3
x, y = np.meshgrid(
    np.linspace(-x_max, x_max, int(4*x_max+1)), 
    np.linspace(-y_max, y_max, int(4*y_max+1))
)
dy = np.exp(-y)
mag = np.hypot(1, dy)
plt.quiver(
    x, y, 
    1/mag, dy/mag, 
    dy, 
    cmap = cmap,
    norm = colors.LogNorm(vmin=1/32, vmax=32),
    pivot = "mid",
    scale = 19,
)
plt.colorbar()
plt.title("dy/dx = exp(-y)")
plt.tight_layout()
# plt.savefig(f"./svg/log_x_slope_field_{cmap}.svg")

plt.show()

# %%
x_max = 4
y_max = 3
x, y = np.meshgrid(
    np.linspace(-x_max, x_max, int(6*x_max+1)), 
    np.linspace(-y_max, y_max, int(6*y_max+1))
)
d = np.vectorize(
    lambda x: 
    (np.pi*x*np.cos(np.pi*x) 
     - np.sin(np.pi*x))/(np.pi*x*x) if x else 0
)
dy = d(x)
mag = np.hypot(1, dy)
v = dy/mag
plt.quiver(
    x, y, 
    1/mag, v, 
    np.abs(dy), 
    cmap = cmap,
    pivot = "mid",
    scale = 27,
)
plt.colorbar()
plt.title(f"dy/dx = ({pi_chr}xcos({pi_chr}x)-sin({pi_chr}x))/({pi_chr}x^2)")
plt.tight_layout()
# plt.savefig(f"./svg/sinc_x_slope_field_{cmap}.svg")

plt.show()

# %%
x_max = 4
y_max = 3
x, y = np.meshgrid(
    np.linspace(-x_max, x_max, int(6*x_max+1)), 
    np.linspace(-y_max, y_max, int(6*y_max+1))
)
d = np.vectorize(
    lambda x, y: 
    (np.cos(np.pi*x) - y)/x if x else
    0 if y == 1 else
    np.nan
)
dy = d(x, y)
mag = np.hypot(1, dy)
v = dy/mag
plt.quiver(
    x, y, 
    1/mag, v, 
    np.abs(dy), 
    cmap = cmap,
    norm = colors.Normalize(vmin=0, vmax=11),
    pivot = "mid",
    scale = 27,
)
plt.colorbar()
plt.title(f"dy/dx = (cos({pi_chr}x)-y)/x")
plt.tight_layout()
# plt.savefig(f"./svg/sinc_x_2_slope_field_{cmap}.svg")

plt.show()

# %%
x_max = 4
y_max = 3
x, y = np.meshgrid(
    np.linspace(-x_max, x_max, 4*x_max+1), 
    np.linspace(-y_max, y_max, 4*y_max+1)
)
dy = -2*x*y
mag = np.hypot(1, dy)
u = 1/mag
v = dy/mag
plt.quiver(
    x, y, 
    u, v, 
    np.abs(dy), 
    cmap = cmap,
    pivot = "mid",
    scale = 20,
)
plt.colorbar()
plt.title("dy/dx = -2xy")
plt.tight_layout()
# plt.savefig(f"./svg/gaussian_slope_field_{cmap}.svg")

plt.show()

# %%
x_max = 4
y_max = 3
x, y = np.meshgrid(
    np.linspace(-x_max, x_max, 4*x_max+1), 
    np.linspace(-y_max, y_max, 4*y_max+1)
)

dy = np.vectorize(lambda y, x:
    np.nan if x == 0 else y/x)(y, x)
mag = np.hypot(1, dy)
u = 1/mag
v = dy/mag
plt.quiver(
    x, y, 
    u, v, 
    np.abs(dy), 
    cmap = cmap,
    pivot = "mid",
    scale = 20,
)
plt.colorbar()
plt.title("dy/dx = y/x")
plt.tight_layout()
# plt.savefig(f"./svg/line_slope_field_{cmap}.svg")

plt.show()

# %%
x_max = 4
y_max = 3
x, y = np.meshgrid(
    np.linspace(-x_max, x_max, 4*x_max+1), 
    np.linspace(-y_max, y_max, 4*y_max+1)
)

dy = np.vectorize(
    lambda x, y:
    # -1e20 if x == 0 and y > 0 else
    # 1e20 if x == 0 and y < 0 else
    np.nan if x == 0 else
    y/x)(x, y)
mag = np.hypot(1, dy)
u = 1/mag
v = -dy/mag
plt.quiver(
    x, y, 
    u, v, 
    np.abs(dy), 
    cmap = cmap,
    norm = colors.Normalize(vmin=0, vmax=6),
    pivot = "mid",
    scale = 20,
)
plt.colorbar()
plt.title("dy/dx = -y/x")
plt.tight_layout()
# plt.savefig(f"./svg/one_over_x_slope_field_{cmap}.svg")

plt.show()

# %%
x_max = 4
y_max = 3
x, y = np.meshgrid(
    np.linspace(-x_max, x_max, 4*x_max+1), 
    np.linspace(-y_max, y_max, 4*y_max+1)
)

dy = np.vectorize(
    lambda y, x:
    # -1e20 if x == 0 and y > 0 else
    # 1e20 if x == 0 and y < 0 else
    np.nan if x == 0 else
    2*y/x)(y, x)
mag = np.hypot(1, dy)
u = 1/mag
v = -dy/mag
plt.quiver(
    x, y, 
    u, v, 
    np.abs(dy), 
    cmap = cmap,
    norm = colors.Normalize(vmin=0, vmax=12),
    pivot = "mid",
    scale = 20,
)
plt.colorbar()
plt.title("dy/dx = -2y/x")
plt.tight_layout()
# plt.savefig(f"./svg/one_over_x_squared_slope_field_{cmap}.svg")

plt.show()

# %%
x_max = 8
y_max = 6
x, y = np.meshgrid(
    np.linspace(-x_max, x_max, 2*x_max+1), 
    np.linspace(-y_max, y_max, 2*y_max+1)
)
dy = np.vectorize(lambda x, y: x/y if y else np.nan)(x, y)
mag = np.hypot(1, dy)
mag[mag == 0] = np.nan
u = 1/mag
v = -dy/mag
plt.quiver(
    x, y, 
    u, v, 
    np.abs(dy), 
    cmap = cmap,
    pivot = "mid",
    scale = 19,
)
plt.colorbar()
plt.title("dy/dx = -x/y")
plt.tight_layout()
# plt.savefig(f"./svg/circle_slope_field_{cmap}.svg")

plt.show()

plt.clf()
v = dy/mag
plt.quiver(
    x, y, 
    u, v, 
    np.abs(dy), 
    cmap = cmap,
    pivot = "mid",
    scale = 19,
)
plt.colorbar()
plt.title("dy/dx = x/y")
plt.tight_layout()
# plt.savefig(f"./svg/hyperbola_slope_field_{cmap}.svg")

plt.show()

# %%
x_max = 4
y_max = 3
x, y = np.meshgrid(
    np.linspace(-x_max, x_max, 4*x_max+1), 
    np.linspace(-y_max, y_max, 4*y_max+1)
)

dy = np.arctan2(y, x)
mag = np.hypot(1, dy)
u = 1/mag
v = dy/mag
plt.quiver(
    x, y, 
    u, v, 
    np.abs(dy), 
    cmap = cmap,
    pivot = "mid",
    scale = 20,
)
plt.colorbar()
plt.title("dy/dx = atan2(y, x)")
plt.tight_layout()
# plt.savefig(f"./svg/slope_arctan2_slope_field_{cmap}.svg")

plt.show()

# %%
x_max = 4
y_max = 3
x, y = np.meshgrid(
    np.linspace(-x_max, x_max, 4*x_max+1), 
    np.linspace(-y_max, y_max, 4*y_max+1)
)

dy = np.arctan(y)
mag = np.hypot(1, dy)
u = 1/mag
v = dy/mag
plt.quiver(
    x, y, 
    u, v, 
    np.abs(dy), 
    cmap = cmap,
    pivot = "mid",
    scale = 20,
)
plt.colorbar()
plt.title("dy/dx = arctan(y)")
plt.tight_layout()
# plt.savefig(f"./svg/slope_arctan_y_slope_field_{cmap}.svg")

plt.show()
